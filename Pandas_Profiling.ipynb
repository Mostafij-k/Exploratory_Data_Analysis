# %%
# Pandas Profiling: Python tool that automatically generates an Exploratory Data Analysis (EDA) report
# It helps you understand your dataset quickly
# officially called ydata-profiling

# Install ydata-profiling
! pip install ydata-profiling
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 6.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.0 MB 4.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.0 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 3.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 3.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 3.3 MB/s eta 0:00:01
# ...

# %%
# Import profiling labraries
from ydata_profiling import ProfileReport
import pandas as pd

# %%
# Import dataset
Df=pd.read_csv('titanic.csv')

# %%
# Now work with pandas profiling
Prf=ProfileReport(Df)
Prf.to_file(output_file='output.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 56.55it/s]
